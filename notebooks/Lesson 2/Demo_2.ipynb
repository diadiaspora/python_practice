# %%
my_tuple = (10, "Python", 3.14, "AI", 42, "Data", 7.89, "Machine Learning")

# %%
print(my_tuple)
# Out:
# (10, 'Python', 3.14, 'AI', 42, 'Data', 7.89, 'Machine Learning')

# %%
positive_indexing = my_tuple[1]

# %%
print(positive_indexing)
# Out:
# Python

# %%
negative_indexing = my_tuple[-2]

# %%
print(negative_indexing)
# Out:
# 7.89

# %%
sub_tuple = my_tuple[2:6]

# %%
print(sub_tuple)
# Out:
# (3.14, 'AI', 42, 'Data')

# %%
my_tuple[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 my_tuple[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(my_tuple)
# Out:
# (10, 'Python', 3.14, 'AI', 42, 'Data', 7.89, 'Machine Learning')

# %%
a, b, c, d, e, f, g, h = my_tuple

# %%
print(a,b,c,d,e,f,g,h)
# Out:
# 10 Python 3.14 AI 42 Data 7.89 Machine Learning

# %%
print(my_tuple)
# Out:
# (10, 'Python', 3.14, 'AI', 42, 'Data', 7.89, 'Machine Learning')

# %%
element_count = my_tuple.count("Python")

# %%
print(element_count)
# Out:
# 1

# %%
element_index = my_tuple.index(42)

# %%
print(element_index)
# Out:
# 4

# %%
temp_list = list(my_tuple)

# %%
print(temp_list)
# Out:
# [10, 'Python', 3.14, 'AI', 42, 'Data', 7.89, 'Machine Learning']

# %%
temp_list.append("Deep Learning")

# %%
print(temp_list)
# Out:
# [10, 'Python', 3.14, 'AI', 42, 'Data', 7.89, 'Machine Learning', 'Deep Learning']

# %%
temp_list.remove(3.14)

# %%
print(temp_list)
# Out:
# [10, 'Python', 'AI', 42, 'Data', 7.89, 'Machine Learning', 'Deep Learning']

# %%
modified_tuple = tuple(temp_list)

# %%
print(modified_tuple)
# Out:
# (10, 'Python', 'AI', 42, 'Data', 7.89, 'Machine Learning', 'Deep Learning')
