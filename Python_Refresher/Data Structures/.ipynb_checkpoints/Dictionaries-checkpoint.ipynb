# %%
student_dict = {
    "name": "John Doe",
    "age": 21,
    "course": "Computer Science",
    "marks": 85,
    "city": "New York"
}

# %%
print(student_dict)
# Out:
# {'name': 'John Doe', 'age': 21, 'course': 'Computer Science', 'marks': 85, 'city': 'New York'}

# %%
student_name = student_dict["name"]

# %%
print(student_name)
# Out:
# John Doe

# %%
student_course = student_dict["course"]

# %%
print(student_course)
# Out:
# Computer Science

# %%
student_dict["marks"] = 90

# %%
print(student_dict)
# Out:
# {'name': 'John Doe', 'age': 21, 'course': 'Computer Science', 'marks': 90, 'city': 'New York'}

# %%
student_dict["email"] = "johndoe@example.com"

# %%
print(student_dict)
# Out:
# {'name': 'John Doe', 'age': 21, 'course': 'Computer Science', 'marks': 90, 'city': 'New York', 'email': 'johndoe@example.com'}

# %%
removed_value = student_dict.pop("city")

# %%
print(student_dict)
# Out:
# {'name': 'John Doe', 'age': 21, 'course': 'Computer Science', 'marks': 90, 'email': 'johndoe@example.com'}

# %%
print(student_dict["email"])
print(removed_value)
# Out:
# johndoe@example.com
# New York

# %%
all_keys = list(student_dict.keys())

# %%
print(all_keys)
# Out:
# ['name', 'age', 'course', 'marks', 'email']

# %%
all_values = list(student_dict.values())

# %%
print(all_values)
# Out:
# ['John Doe', 21, 'Computer Science', 90, 'johndoe@example.com']

# %%
all_items = list(student_dict.items())

# %%
print(all_items)
# Out:
# [('name', 'John Doe'), ('age', 21), ('course', 'Computer Science'), ('marks', 90), ('email', 'johndoe@example.com')]

# %%
existing_value = student_dict.get("course")

# %%
print(existing_value)
# Out:
# Computer Science

# %%
non_existing_value = student_dict.get("phone")

# %%
print(non_existing_value)
# Out:
# None

# %%
non_existing_value = student_dict.get("phone", "Key not found")

# %%
print(non_existing_value)
# Out:
# Key not found
